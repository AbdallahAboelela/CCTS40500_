# %% [markdown]
# ### CCTS 40500: FINAL
# #### Abdallah Aboelela

# %%
# General
import numpy as np
import pandas as pd

# For plotting
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable

# Keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils

# Sklearn
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold, train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# For fun
from sklearn.ensemble import RandomForestClassifier

# %%
# setup
seed = 7
np.random.seed(seed)
files = ['hiv-db-LTNP.seq', 'hiv-db-SP.seq', 'hiv-db-zRP.seq']

# %%
# load dataset
combined = pd.DataFrame()
for fname in files:
    df = pd.read_csv('data/' + fname, header = None)
    df['type'] = fname
    combined = pd.concat([combined, df])
    
combined = combined.replace('hiv-db-LTNP.seq', 'LTNP')
combined = combined.replace('hiv-db-zRP.seq', 'RP')
combined = combined.replace('hiv-db-SP.seq', 'SP')

combined.columns = ['seq', 'type']
combined['len'] = combined.seq.apply(len)

# %%
for i in range(max(combined.len)):
    combined[i] = combined.seq.apply(lambda x: get_position(x, i))
    
combined = combined.drop(['seq', 'len'], axis = 1)

# %%
combined = combined.replace(['A', 'T', 'G', 'C'], list(range(4)))
combined = combined.replace(np.nan, int(4))

# %% [markdown]
# #### Attempt using random forest

# %%
rf_clf = RandomForestClassifier(n_estimators = 100)
kfold = KFold(n_splits=10, shuffle=True, random_state = seed)
results = cross_val_score(rf_clf, combined.drop('type', axis = 1), combined.type, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Baseline: 74.89% (10.96%)

# %% [markdown]
# #### Attempt at Neural Net

# %%
k_clf = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=5, verbose=0)
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(k_clf, combined.drop('type', axis = 1), combined.type, cv=kfold, error_score = 'raise')
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Baseline: 43.57% (15.41%)

# %% [markdown]
# #### Attempt at creating anauto-encoder/decoder

# %%
X_train, X_test, y_train, y_test = train_test_split(combined.drop('type', axis = 1), 
                                                    combined.type, random_state=seed)

# %%
# this is the size of our encoded representations
encoding_dim = 410  # 9840 ints -> compression of factor 24, assuming the input is 9840 floats

# this is our input placeholder
input_img = Input(shape=(9840,))

# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)

# "decoded" is the lossy reconstruction of the input
decoded = Dense(9840, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)

# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# create a placeholder for an encoded (n-dimensional) input
encoded_input = Input(shape=(encoding_dim,))

# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]

# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
autoencoder.fit(X_train, X_train,
                epochs=75,
                batch_size=256,
                shuffle=True,
                validation_data=(X_test, X_test))
# Out:
# Train on 101 samples, validate on 34 samples
# Epoch 1/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0315 - val_loss: -7.2930
# Epoch 2/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0379 - val_loss: -7.2961
# Epoch 3/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0429 - val_loss: -7.3002
# Epoch 4/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0489 - val_loss: -7.3038
# Epoch 5/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0546 - val_loss: -7.3105
# Epoch 6/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0605 - val_loss: -7.3129
# Epoch 7/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0649 - val_loss: -7.3195
# Epoch 8/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0728 - val_loss: -7.3231
# Epoch 9/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0771 - val_loss: -7.3279
# Epoch 10/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0837 - val_loss: -7.3309
# Epoch 11/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0879 - val_loss: -7.3376
# Epoch 12/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.0959 - val_loss: -7.3408
# Epoch 13/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1006 - val_loss: -7.3472
# Epoch 14/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1081 - val_loss: -7.3500
# Epoch 15/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1116 - val_loss: -7.3577
# Epoch 16/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1202 - val_loss: -7.3596
# Epoch 17/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1240 - val_loss: -7.3673
# Epoch 18/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1318 - val_loss: -7.3693
# Epoch 19/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1339 - val_loss: -7.3770
# Epoch 20/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1440 - val_loss: -7.3785
# Epoch 21/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1448 - val_loss: -7.3877
# Epoch 22/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1546 - val_loss: -7.3873
# Epoch 23/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.1543 - val_loss: -7.3976
# Epoch 24/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.1676 - val_loss: -7.3974
# Epoch 25/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.1666 - val_loss: -7.4084
# Epoch 26/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.1790 - val_loss: -7.4064
# Epoch 27/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1777 - val_loss: -7.4196
# Epoch 28/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1920 - val_loss: -7.4173
# Epoch 29/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.1897 - val_loss: -7.4315
# Epoch 30/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2031 - val_loss: -7.4256
# Epoch 31/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2000 - val_loss: -7.4408
# Epoch 32/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2146 - val_loss: -7.4370
# Epoch 33/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.2125 - val_loss: -7.4531
# Epoch 34/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2280 - val_loss: -7.4467
# Epoch 35/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2245 - val_loss: -7.4637
# Epoch 36/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.2398 - val_loss: -7.4576
# Epoch 37/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2355 - val_loss: -7.4750
# Epoch 38/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2515 - val_loss: -7.4709
# Epoch 39/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.2498 - val_loss: -7.4863
# Epoch 40/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.2657 - val_loss: -7.4823
# Epoch 41/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2616 - val_loss: -7.4972
# Epoch 42/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2781 - val_loss: -7.4915
# Epoch 43/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2724 - val_loss: -7.5090
# Epoch 44/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2893 - val_loss: -7.5026
# Epoch 45/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2837 - val_loss: -7.5190
# Epoch 46/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3018 - val_loss: -7.5164
# Epoch 47/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.2981 - val_loss: -7.5317
# Epoch 48/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.3150 - val_loss: -7.5262
# Epoch 49/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3091 - val_loss: -7.5428
# Epoch 50/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3260 - val_loss: -7.5355
# Epoch 51/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.3193 - val_loss: -7.5539
# Epoch 52/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.3382 - val_loss: -7.5483
# Epoch 53/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3329 - val_loss: -7.5636
# Epoch 54/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3504 - val_loss: -7.5581
# Epoch 55/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3441 - val_loss: -7.5746
# Epoch 56/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3608 - val_loss: -7.5687
# Epoch 57/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3544 - val_loss: -7.5848
# Epoch 58/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3734 - val_loss: -7.5810
# Epoch 59/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3674 - val_loss: -7.5955
# Epoch 60/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.3852 - val_loss: -7.5906
# Epoch 61/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3768 - val_loss: -7.6033
# Epoch 62/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.3954 - val_loss: -7.5995
# Epoch 63/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.3868 - val_loss: -7.6132
# Epoch 64/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.4053 - val_loss: -7.6092
# Epoch 65/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.3968 - val_loss: -7.6222
# Epoch 66/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.4171 - val_loss: -7.6188
# Epoch 67/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.4076 - val_loss: -7.6323
# Epoch 68/75
# 101/101 [==============================] - 0s 3ms/step - loss: -7.4270 - val_loss: -7.6290
# Epoch 69/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.4183 - val_loss: -7.6418
# Epoch 70/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.4387 - val_loss: -7.6381
# Epoch 71/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.4290 - val_loss: -7.6504
# Epoch 72/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.4490 - val_loss: -7.6502
# Epoch 73/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.4403 - val_loss: -7.6613
# Epoch 74/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.4600 - val_loss: -7.6583
# Epoch 75/75
# 101/101 [==============================] - 0s 2ms/step - loss: -7.4507 - val_loss: -7.6689

# %%
# encode and decode some sequences
# note that we take them from the *test* set
encoded_imgs = encoder.predict(X_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
n = 10  # how many sequences we will display
dz = [0, 1, 2, 3, 4]
norm = plt.Normalize()
colors = plt.cm.jet(norm(dz))
plt.figure(figsize=(20, 8))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(np.array(X_test.iloc[i, :]).reshape(164, 60))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(164, 60))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

## NEED TO ADD COLORS TO THIS

# %% [markdown]
# ##### This doesn't seem to be working too well...

# %%
matplotlib.cm.[source]

# %%
colors
# Out:
# array([[0.        , 0.        , 0.5       , 1.        ],
#        [0.        , 0.50392157, 1.        , 1.        ],
#        [0.49019608, 1.        , 0.47754586, 1.        ],
#        [1.        , 0.58169935, 0.        , 1.        ],
#        [0.5       , 0.        , 0.        , 1.        ]])

# %% [markdown]
# ## Appendix

# %%
def get_position(x, i):
    try:
        return x[i]
        
    except Exception as e:
        return np.nan

# %%
# define baseline model
def baseline_model():
    # create model
    model = Sequential()
    model.add(Dense(8, input_dim=9840, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
